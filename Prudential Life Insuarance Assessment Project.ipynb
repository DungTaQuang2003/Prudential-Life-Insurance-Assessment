# %% [markdown]
# # **Import thư viện**

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns


from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
# Out:
# <ipython-input-1-7fc38a86132f>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# # **Đọc dữ liệu**

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/DATA MINING/Project Midterm Test_Prudential')
# Out:
# Mounted at /content/drive

# %%
# from zipfile import ZipFile
# import zipfile

# filepath = os.getcwd()
# with zipfile.ZipFile('./prudential-life-insurance-assessment.zip','r') as zip_file:
#     zip_file.extractall(filepath)

# %%
# filepath = os.getcwd()
# with zipfile.ZipFile('./train.csv.zip','r') as zip_file:
#     zip_file.extractall(filepath)

# %%
# filepath = os.getcwd()
# with zipfile.ZipFile('./test.csv.zip','r') as zip_file:
#     zip_file.extractall(filepath)

# %% [markdown]
# Trong tập dữ liệu này, ta được cung cấp hơn một trăm biến mô tả các thuộc tính của người đăng ký bảo hiểm nhân thọ. Nhiệm vụ là dự đoán biến "Phản hồi" cho từng ID khách hàng trong tập dữ liệu kiểm tra. "Phản hồi" là thước đo rủi ro thứ tự có 8 cấp độ.

# %%
df_train = pd.read_csv('./train.csv')
# df_train = pd.read_csv('/kaggle/input/prudential-life-insurance-assessment/train.csv.zip')
df_train
# Out:
#           Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0          2               1             D3              10        0.076923
# 1          5               1             A1              26        0.076923
# 2          6               1             E1              26        0.076923
# 3          7               1             D4              10        0.487179
# 4          8               1             D2              26        0.230769
# ...      ...             ...            ...             ...             ...
# 59376  79142               1             D1              10        0.230769
# 59377  79143               1             D3              26        0.230769
# 59378  79144               1             E1              26        0.076923
# 59379  79145               1             D2              10        0.230769
# 59380  79146               1             A8              26        0.076923
#
#        Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# 0                   2               1               1  0.641791  0.581818
# 1                   2               3               1  0.059701  0.600000
# 2                   2               3               1  0.029851  0.745455
# 3                   2               3               1  0.164179  0.672727
# 4                   2               3               1  0.417910  0.654545
# ...               ...             ...             ...       ...       ...
# 59376               2               3               1  0.074627  0.709091
# 59377               2               3               1  0.432836  0.800000
# 59378               2               3               1  0.104478  0.745455
# 59379               2               3               1  0.507463  0.690909
# 59380               2               3               1  0.447761  0.781818
#
#        ...  Medical_Keyword_40  Medical_Keyword_41  Medical_Keyword_42  \
# 0      ...                   0                   0                   0
# 1      ...                   0                   0                   0
# 2      ...                   0                   0                   0
# 3      ...                   0                   0                   0
# 4      ...                   0                   0                   0
# ...    ...                 ...                 ...                 ...
# 59376  ...                   0                   0                   0
# 59377  ...                   0                   0                   0
# 59378  ...                   0                   0                   0
# 59379  ...                   1                   0                   0
# 59380  ...                   0                   0                   0
#
#        Medical_Keyword_43  Medical_Keyword_44  Medical_Keyword_45  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 59376                   0                   0                   0
# 59377                   0                   0                   0
# 59378                   0                   0                   0
# 59379                   0                   0                   0
# 59380                   0                   0                   0
#
#        Medical_Keyword_46  Medical_Keyword_47  Medical_Keyword_48  Response
# 0                       0                   0                   0         8
# 1                       0                   0                   0         4
# 2                       0                   0                   0         8
# 3                       0                   0                   0         8
# 4                       0                   0                   0         8
# ...                   ...                 ...                 ...       ...
# 59376                   0                   0                   0         4
# 59377                   0                   0                   0         7
# 59378                   0                   0                   0         8
# 59379                   0                   0                   0         8
# 59380                   0                   0                   0         7
#
# [59381 rows x 128 columns]

# %%
df_train.shape
# Out:
# (59381, 128)

# %%
df_train.columns
# Out:
# Index(['Id', 'Product_Info_1', 'Product_Info_2', 'Product_Info_3',
#        'Product_Info_4', 'Product_Info_5', 'Product_Info_6', 'Product_Info_7',
#        'Ins_Age', 'Ht',
#        ...
#        'Medical_Keyword_40', 'Medical_Keyword_41', 'Medical_Keyword_42',
#        'Medical_Keyword_43', 'Medical_Keyword_44', 'Medical_Keyword_45',
#        'Medical_Keyword_46', 'Medical_Keyword_47', 'Medical_Keyword_48',
#        'Response'],
#       dtype='object', length=128)

# %% [markdown]
# **Thông tin về các thuộc tính trong bảng dữ liệu:**
# - Id:	Mã định danh duy nhất gắn liền với một đơn nộp.
# - Product_Info_1-7:	Tập hợp các biến chuẩn hóa liên quan đến sản phẩm áp dụng cho
# - Ins_Age:	Độ tuổi chuẩn hóa của người nộp đơn
# - Ht:	Chiều cao chuẩn hóa của người nộp đơn
# - Wt:	Cân nặng chuẩn hóa của người nộp đơn
# - BMI:	BMI chuẩn hóa của người nộp đơn
# - Employment_Info_1-6:	Tập hợp các biến chuẩn hóa liên quan đến lịch sử việc làm của người nộp đơn.
# - InsuredInfo_1-6:	Tập hợp các biến chuẩn hóa cung cấp thông tin về người nộp đơn.
# - Insurance_History_1-9:	Tập hợp các biến chuẩn hóa liên quan đến lịch sử bảo hiểm của người nộp đơn.
# - Family_Hist_1-5	A: tập hợp các biến chuẩn hóa liên quan đến lịch sử gia đình của người nộp đơn.
# - Medical_History_1-41:	Tập hợp các biến chuẩn hóa liên quan đến bệnh sử của người nộp đơn.
# - Medical_Keyword_1-48:	Tập hợp các biến giả liên quan đến sự hiện diện/không có của từ khóa y tế được liên kết với đơn nộp.
# - Response:	Đây là biến mục tiêu, biến thứ tự liên quan đến quyết định cuối cùng liên quan đến một đơn nộp.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59381 entries, 0 to 59380
# Columns: 128 entries, Id to Response
# dtypes: float64(18), int64(109), object(1)
# memory usage: 58.0+ MB

# %%
df_train.dtypes
# Out:
# Id                      int64
# Product_Info_1          int64
# Product_Info_2         object
# Product_Info_3          int64
# Product_Info_4        float64
#                        ...
# Medical_Keyword_45      int64
# Medical_Keyword_46      int64
# Medical_Keyword_47      int64
# Medical_Keyword_48      int64
# Response                int64
# Length: 128, dtype: object

# %% [markdown]
# # **Tiền xử lý dữ liệu - Train Dataset**

# %% [markdown]
# ## **Kiểm tra Missing Value**

# %%
check_nan = df_train.isna().sum()
check_nan[check_nan > 0]
# Out:
# Employment_Info_1         19
# Employment_Info_4       6779
# Employment_Info_6      10854
# Insurance_History_5    25396
# Family_Hist_2          28656
# Family_Hist_3          34241
# Family_Hist_4          19184
# Family_Hist_5          41811
# Medical_History_1       8889
# Medical_History_10     58824
# Medical_History_15     44596
# Medical_History_24     55580
# Medical_History_32     58274
# dtype: int64

# %%
total_miss = df_train.isna().sum().sort_values(ascending = False)
percent = ((df_train.isna().sum()/df_train.shape[0])*100).sort_values(ascending = False)

total_miss = total_miss[total_miss > 0]
percent = percent[percent > 0]

missing_data = pd.concat([total_miss, percent], axis = 1, keys = ['Total Miss', 'Percent'])
missing_data.reset_index(inplace=True)
missing_data.rename(columns={'index': 'Columns'}, inplace=True)
missing_data
# Out:
#                 Columns  Total Miss    Percent
# 0    Medical_History_10       58824  99.061990
# 1    Medical_History_32       58274  98.135767
# 2    Medical_History_24       55580  93.598963
# 3    Medical_History_15       44596  75.101463
# 4         Family_Hist_5       41811  70.411411
# 5         Family_Hist_3       34241  57.663226
# 6         Family_Hist_2       28656  48.257860
# 7   Insurance_History_5       25396  42.767889
# 8         Family_Hist_4       19184  32.306630
# 9     Employment_Info_6       10854  18.278574
# 10    Medical_History_1        8889  14.969435
# 11    Employment_Info_4        6779  11.416110
# 12    Employment_Info_1          19   0.031997

# %%
plt.figure(figsize=(10, 6))
plt.barh(missing_data['Columns'], missing_data['Percent'], color='royalblue')
plt.xlabel('Percentage of Missing Values')
plt.ylabel('Columns')
plt.title('Missing Values Percentage by Column')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# Dựa trên biểu đồ tỉ lệ NULL của mỗi cột thuộc tính, ta nhận thấy:
# - Đa số các cột đều có tỉ lệ giá trị bị thiếu trên 30%, riêng chỉ có các cột 'Employment_Info_1', 'Employment_Info_6', 'Family_Hist_1' là thấp(dưới 20%)
# - Nguyên nhân có thể là do khách hàng này họ chưa từng có lịch sử khám chữa bệnh này hoặc là chưa từng làm công việc đó nên thông tin sẽ bị khuyết.
#
# => Xử lý:
# - Ta sẽ nhặt ra những cột bị NULL trên 30% và drop.
# - Những cột NULL ít còn lại thì sẽ fillna bằng mean hoặc là median.

# %%
# Lọc những cột có tỷ lệ Null trên 30%
nacols_above30 = missing_data[missing_data['Percent'] > 30]['Columns']
nacols_above30
# Out:
# 0     Medical_History_10
# 1     Medical_History_32
# 2     Medical_History_24
# 3     Medical_History_15
# 4          Family_Hist_5
# 5          Family_Hist_3
# 6          Family_Hist_2
# 7    Insurance_History_5
# 8          Family_Hist_4
# Name: Columns, dtype: object

# %%
df_train[['Employment_Info_1', 'Employment_Info_4', 'Employment_Info_6', 'Medical_History_1']].dtypes
# Out:
# Employment_Info_1    float64
# Employment_Info_4    float64
# Employment_Info_6    float64
# Medical_History_1    float64
# dtype: object

# %%
df_train[['Employment_Info_1', 'Employment_Info_4', 'Employment_Info_6', 'Medical_History_1']].describe()
# Out:
#        Employment_Info_1  Employment_Info_4  Employment_Info_6  \
# count       59362.000000       52602.000000       48527.000000
# mean            0.077582           0.006283           0.361469
# std             0.082347           0.032816           0.349551
# min             0.000000           0.000000           0.000000
# 25%             0.035000           0.000000           0.060000
# 50%             0.060000           0.000000           0.250000
# 75%             0.100000           0.000000           0.550000
# max             1.000000           1.000000           1.000000
#
#        Medical_History_1
# count       50492.000000
# mean            7.962172
# std            13.027697
# min             0.000000
# 25%             2.000000
# 50%             4.000000
# 75%             9.000000
# max           240.000000

# %%
df_train = df_train.drop(columns = nacols_above30, axis = 1)
df_train.shape
# Out:
# (59381, 119)

# %%
check_nan = df_train.isna().sum()
check_nan[check_nan > 0]
# Out:
# Employment_Info_1       19
# Employment_Info_4     6779
# Employment_Info_6    10854
# Medical_History_1     8889
# dtype: int64

# %%
columns_to_fill = ['Employment_Info_1', 'Employment_Info_4', 'Employment_Info_6', 'Medical_History_1']
df_train[columns_to_fill] = df_train[columns_to_fill].fillna(df_train[columns_to_fill].mean())

# %%
check_nan = df_train.isna().sum()
check_nan[check_nan > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## **Kiểm tra dữ liệu Duplicated**

# %%
train_duplicated = df_train.duplicated().sum()
train_duplicated
# Out:
# 0

# %% [markdown]
# **Dữ liệu không xuất hiện giá trị bị trùng lặp.**

# %% [markdown]
# ## **Kiểm tra lỗi Logic và Outlier**

# %%
# def find_outliers(df):
#     q1=df.quantile(0.25)
#     q3=df.quantile(0.75)
#     IQR=q3-q1
#     lower= q1 - 1.5*IQR
#     upper = q3 + 1.5*IQR
#     outliers = df[((df < lower) | (df > upper))]
#     return outliers, lower, upper

# outliers1, lower, upper = find_outliers(df_train_new)
# outliers1_perc = (outliers1.count()/df_train.shape[0] * 100 )
# out_cols= outliers1_perc.loc[outliers1_perc.index [outliers1_perc > 0]]
# print (out_cols)
# outlier_ls =list(out_cols.index)
# outlier_ls

# %%
response_counts = df_train['Response'].value_counts()
response_counts
# Out:
# Response
# 8    19489
# 6    11233
# 7     8027
# 2     6552
# 1     6207
# 5     5432
# 4     1428
# 3     1013
# Name: count, dtype: int64

# %%
values = response_counts.values
labels = response_counts.index

plt.figure(figsize=(10, 6))
sns.barplot(x = labels, y = values, color='royalblue')
plt.xlabel('Response')
plt.ylabel('Value Counts')
plt.title('Response Number Distribution Chart')
plt.show()

# %% [markdown]
# **Nhận xét:**
# - Biến đầu ra gồm có 8 giá trị, response_8 là giá trị mà xuất hiện nhiều nhất
# - Mức độ phân bổ của nhãn bị mất cân bằng
#
# => Xử lý: Dùng resampling để cân bằng lại nhãn.

# %%
categorical_cols =  [col for col in df_train.columns if df_train[col].dtype =='object']
print("Dữ liệu định tính:", categorical_cols)
# Out:
# Dữ liệu định tính: ['Product_Info_2']

# %%
numerical_cols =  [col for col in df_train.columns if df_train[col].dtype !='object']
print("Dữ liệu định lượng:",numerical_cols)
# Out:
# Dữ liệu định lượng: ['Id', 'Product_Info_1', 'Product_Info_3', 'Product_Info_4', 'Product_Info_5', 'Product_Info_6', 'Product_Info_7', 'Ins_Age', 'Ht', 'Wt', 'BMI', 'Employment_Info_1', 'Employment_Info_2', 'Employment_Info_3', 'Employment_Info_4', 'Employment_Info_5', 'Employment_Info_6', 'InsuredInfo_1', 'InsuredInfo_2', 'InsuredInfo_3', 'InsuredInfo_4', 'InsuredInfo_5', 'InsuredInfo_6', 'InsuredInfo_7', 'Insurance_History_1', 'Insurance_History_2', 'Insurance_History_3', 'Insurance_History_4', 'Insurance_History_7', 'Insurance_History_8', 'Insurance_History_9', 'Family_Hist_1', 'Medical_History_1', 'Medical_History_2', 'Medical_History_3', 'Medical_History_4', 'Medical_History_5', 'Medical_History_6', 'Medical_History_7', 'Medical_History_8', 'Medical_History_9', 'Medical_History_11', 'Medical_History_12', 'Medical_History_13', 'Medical_History_14', 'Medical_History_16', 'Medical_History_17', 'Medical_History_18', 'Medical_History_19', 'Medical_History_20', 'Medical_History_21', 'Medical_History_22', 'Medical_History_23', 'Medical_History_25', 'Medical_History_26', 'Medical_History_27', 'Medical_History_28', 'Medical_History_29', 'Medical_History_30', 'Medical_History_31', 'Medical_History_33', 'Medical_History_34', 'Medical_History_35', 'Medical_History_36', 'Medical_History_37', 'Medical_History_38', 'Medical_History_39', 'Medical_History_40', 'Medical_History_41', 'Medical_Keyword_1', 'Medical_Keyword_2', 'Medical_Keyword_3', 'Medical_Keyword_4', 'Medical_Keyword_5', 'Medical_Keyword_6', 'Medical_Keyword_7', 'Medical_Keyword_8', 'Medical_Keyword_9', 'Medical_Keyword_10', 'Medical_Keyword_11', 'Medical_Keyword_12', 'Medical_Keyword_13', 'Medical_Keyword_14', 'Medical_Keyword_15', 'Medical_Keyword_16', 'Medical_Keyword_17', 'Medical_Keyword_18', 'Medical_Keyword_19', 'Medical_Keyword_20', 'Medical_Keyword_21', 'Medical_Keyword_22', 'Medical_Keyword_23', 'Medical_Keyword_24', 'Medical_Keyword_25', 'Medical_Keyword_26', 'Medical_Keyword_27', 'Medical_Keyword_28', 'Medical_Keyword_29', 'Medical_Keyword_30', 'Medical_Keyword_31', 'Medical_Keyword_32', 'Medical_Keyword_33', 'Medical_Keyword_34', 'Medical_Keyword_35', 'Medical_Keyword_36', 'Medical_Keyword_37', 'Medical_Keyword_38', 'Medical_Keyword_39', 'Medical_Keyword_40', 'Medical_Keyword_41', 'Medical_Keyword_42', 'Medical_Keyword_43', 'Medical_Keyword_44', 'Medical_Keyword_45', 'Medical_Keyword_46', 'Medical_Keyword_47', 'Medical_Keyword_48', 'Response']

# %%
unique_vals = []
for col in categorical_cols:
    uniq_val = df_train[col].unique()
    unique_vals.append(uniq_val)
unique_vals
# Out:
# [array(['D3', 'A1', 'E1', 'D4', 'D2', 'A8', 'A2', 'D1', 'A7', 'A6', 'A3',
#         'A5', 'C4', 'C1', 'B2', 'C3', 'C2', 'A4', 'B1'], dtype=object)]

# %%
for col in categorical_cols:
    counts = df_train[col].value_counts().sort_index()
    if len(counts) > 10 and len(counts) < 50 :
      fig = plt.figure(figsize=(10, 6))
    elif len(counts) >50 :
      continue
    else:
      fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    counts.plot.bar(ax = ax, color='steelblue')
    ax.set_title(col + ' counts')
    ax.set_xlabel(col)
    ax.set_ylabel("Frequency")
plt.show()

# %% [markdown]
# - Dữ liệu của các thuộc tính hầu hết đều bị mất cân bằng.

# %%
for col in numerical_cols:
    counts = df_train[col].value_counts().sort_index()
    if len(counts) > 10 and len(counts) < 50 :
      fig = plt.figure(figsize=(10, 6))
    elif len(counts) > 50 :
      continue
    else:
      fig = plt.figure(figsize=(8, 6))
    ax = fig.gca()
    counts.plot.bar(ax = ax, color='steelblue')
    ax.set_title(col + ' counts')
    ax.set_xlabel(col)
    ax.set_ylabel("Frequency")
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Các cột thuộc tính đặc trưng cũng đều bị vấn đề mất cân bằng giá trị.**

# %%
continuous = ['Product_Info_4', 'Ins_Age', 'Ht', 'Wt', 'BMI', 'Employment_Info_1',
              'Employment_Info_4', 'Employment_Info_6']

plt.figure(figsize=(12, 6))
sns.boxplot(data=df_train[continuous], orient="h", palette="Set2",
            flierprops=dict(markerfacecolor = 'red', marker='D'))
plt.title("Box Plots for Continuous Columns")
plt.xlabel("Value")
plt.show()

# %%
categorical_cols =  [col for col in df_train.columns if df_train[col].dtype =='object']
print("Dữ liệu định tính:", categorical_cols)
# Out:
# Dữ liệu định tính: ['Product_Info_2']

# %%
for col in categorical_cols:
  df_train[col] = pd.factorize(df_train[col])[0]

# %%
#Ma trận tương quan của các biến với Response
variables = df_train[[i for i in df_train.columns if i not in ('Id', 'Response')]]
target = df_train['Response']

# Giá trị tuyệt đối của hệ số tương quan.
corr_matrix = abs(variables.corrwith(target, method='pearson')).sort_values(ascending=False)
correlation_matrix = pd.DataFrame({'corr':corr_matrix})
top_50_corr = correlation_matrix[0:50]

# Tạo bản đồ nhiệt của ma trận tương quan tuyệt đối 50 biến hàng đầu.
plt.figure(figsize=(4, 15))
sns.heatmap(data = top_50_corr, robust= True, annot=True, fmt= '.2g',
                cmap='cool', linewidths=0.01, linecolor= 'white')
plt.title("Correlation Heatmap to Response Variable")
plt.show()

# %%
correlation_matrix[correlation_matrix['corr'] > 0.09].index
# Out:
# Index(['BMI', 'Wt', 'Medical_History_23', 'Medical_Keyword_15',
#        'Medical_Keyword_3', 'Medical_History_4', 'Medical_History_39',
#        'Ins_Age', 'Product_Info_4', 'Medical_Keyword_48', 'Medical_History_6',
#        'Medical_History_16', 'Medical_History_13', 'Medical_History_40',
#        'InsuredInfo_6', 'Insurance_History_2', 'Employment_Info_3',
#        'Medical_History_30', 'Medical_Keyword_23', 'Medical_History_33',
#        'Medical_Keyword_25', 'InsuredInfo_5', 'Medical_History_1',
#        'InsuredInfo_7', 'Medical_Keyword_42', 'Ht', 'Medical_Keyword_38',
#        'Medical_History_28', 'Medical_History_18'],
#       dtype='object')

# %%
df_train_new = df_train[['BMI', 'Wt', 'Medical_History_23', 'Medical_Keyword_15',
       'Medical_Keyword_3', 'Medical_History_4', 'Medical_History_39',
       'Ins_Age', 'Product_Info_4', 'Medical_Keyword_48', 'Medical_History_6',
       'Medical_History_16', 'Medical_History_13', 'Medical_History_40',
       'InsuredInfo_6', 'Insurance_History_2', 'Employment_Info_3',
       'Medical_History_30', 'Medical_Keyword_23', 'Medical_History_33',
       'Medical_Keyword_25', 'InsuredInfo_5', 'InsuredInfo_7',
       'Medical_Keyword_42', 'Ht', 'Medical_Keyword_38', 'Medical_History_28',
       'Medical_History_18', 'Response']]
df_train_new
# Out:
#             BMI        Wt  Medical_History_23  Medical_Keyword_15  \
# 0      0.323008  0.148536                   3                   0
# 1      0.272288  0.131799                   3                   0
# 2      0.428780  0.288703                   3                   0
# 3      0.352438  0.205021                   3                   0
# 4      0.424046  0.234310                   3                   0
# ...         ...       ...                 ...                 ...
# 59376  0.519103  0.320084                   3                   0
# 59377  0.551119  0.403766                   3                   0
# 59378  0.360969  0.246862                   3                   0
# 59379  0.462452  0.276151                   3                   0
# 59380  0.539563  0.382845                   3                   0
#
#        Medical_Keyword_3  Medical_History_4  Medical_History_39   Ins_Age  \
# 0                      0                  1                   3  0.641791
# 1                      0                  1                   3  0.059701
# 2                      0                  2                   3  0.029851
# 3                      0                  2                   3  0.164179
# 4                      0                  2                   3  0.417910
# ...                  ...                ...                 ...       ...
# 59376                  0                  1                   3  0.074627
# 59377                  0                  2                   3  0.432836
# 59378                  0                  2                   3  0.104478
# 59379                  0                  1                   3  0.507463
# 59380                  0                  1                   3  0.447761
#
#        Product_Info_4  Medical_Keyword_48  ...  Medical_History_33  \
# 0            0.076923                   0  ...                   1
# 1            0.076923                   0  ...                   3
# 2            0.076923                   0  ...                   3
# 3            0.487179                   0  ...                   3
# 4            0.230769                   0  ...                   3
# ...               ...                 ...  ...                 ...
# 59376        0.230769                   0  ...                   3
# 59377        0.230769                   0  ...                   3
# 59378        0.076923                   0  ...                   3
# 59379        0.230769                   0  ...                   1
# 59380        0.076923                   0  ...                   3
#
#        Medical_Keyword_25  InsuredInfo_5  InsuredInfo_7  Medical_Keyword_42  \
# 0                       0              1              1                   0
# 1                       0              1              1                   0
# 2                       0              1              1                   0
# 3                       0              1              1                   0
# 4                       0              1              1                   0
# ...                   ...            ...            ...                 ...
# 59376                   0              1              1                   0
# 59377                   0              1              1                   0
# 59378                   0              1              1                   0
# 59379                   0              1              1                   0
# 59380                   0              1              1                   0
#
#              Ht  Medical_Keyword_38  Medical_History_28  Medical_History_18  \
# 0      0.581818                   0                   1                   1
# 1      0.600000                   0                   1                   1
# 2      0.745455                   0                   1                   1
# 3      0.672727                   0                   1                   1
# 4      0.654545                   0                   1                   1
# ...         ...                 ...                 ...                 ...
# 59376  0.709091                   0                   1                   1
# 59377  0.800000                   0                   1                   1
# 59378  0.745455                   0                   1                   1
# 59379  0.690909                   0                   1                   1
# 59380  0.781818                   0                   1                   1
#
#        Response
# 0             8
# 1             4
# 2             8
# 3             8
# 4             8
# ...         ...
# 59376         4
# 59377         7
# 59378         8
# 59379         8
# 59380         7
#
# [59381 rows x 29 columns]

# %%
df_train_new['Response'].value_counts()
# Out:
# Response
# 8    19489
# 6    11233
# 7     8027
# 2     6552
# 1     6207
# 5     5432
# 4     1428
# 3     1013
# Name: count, dtype: int64

# %% [markdown]
# # **Tiền xử lý dữ liệu - Test Dataset**

# %%
# df_test = pd.read_csv('/kaggle/input/prudential-life-insurance-assessment/test.csv.zip')
df_test = pd.read_csv('./test.csv')
df_test
# Out:
#           Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0          1               1             D3              26        0.487179
# 1          3               1             A2              26        0.076923
# 2          4               1             D3              26        0.144667
# 3          9               1             A1              26        0.151709
# 4         12               1             A1              26        0.076923
# ...      ...             ...            ...             ...             ...
# 19760  79093               1             D3              26        0.128205
# 19761  79099               1             D4              10        0.230769
# 19762  79102               1             A2              26        0.076923
# 19763  79125               1             D1              26        0.487179
# 19764  79129               1             D3              26        1.000000
#
#        Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# 0                   2               3               1  0.611940  0.781818
# 1                   2               3               1  0.626866  0.727273
# 2                   2               3               1  0.582090  0.709091
# 3                   2               1               1  0.522388  0.654545
# 4                   2               3               1  0.298507  0.672727
# ...               ...             ...             ...       ...       ...
# 19760               2               3               1  0.537313  0.636364
# 19761               2               3               1  0.134328  0.618182
# 19762               2               3               1  0.850746  0.727273
# 19763               2               3               1  0.522388  0.745455
# 19764               2               1               1  0.343284  0.781818
#
#        ...  Medical_Keyword_39  Medical_Keyword_40  Medical_Keyword_41  \
# 0      ...                   0                   0                   0
# 1      ...                   0                   0                   0
# 2      ...                   0                   0                   0
# 3      ...                   0                   0                   0
# 4      ...                   0                   0                   0
# ...    ...                 ...                 ...                 ...
# 19760  ...                   0                   0                   0
# 19761  ...                   0                   0                   0
# 19762  ...                   0                   0                   0
# 19763  ...                   0                   0                   0
# 19764  ...                   0                   0                   0
#
#        Medical_Keyword_42  Medical_Keyword_43  Medical_Keyword_44  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 19760                   0                   0                   0
# 19761                   0                   0                   0
# 19762                   0                   0                   0
# 19763                   0                   0                   0
# 19764                   0                   0                   0
#
#        Medical_Keyword_45  Medical_Keyword_46  Medical_Keyword_47  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   1
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 19760                   0                   0                   0
# 19761                   0                   0                   0
# 19762                   0                   0                   0
# 19763                   0                   0                   0
# 19764                   0                   0                   0
#
#        Medical_Keyword_48
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
# ...                   ...
# 19760                   0
# 19761                   0
# 19762                   0
# 19763                   0
# 19764                   0
#
# [19765 rows x 127 columns]

# %%
df_test.columns
# Out:
# Index(['Id', 'Product_Info_1', 'Product_Info_2', 'Product_Info_3',
#        'Product_Info_4', 'Product_Info_5', 'Product_Info_6', 'Product_Info_7',
#        'Ins_Age', 'Ht',
#        ...
#        'Medical_Keyword_39', 'Medical_Keyword_40', 'Medical_Keyword_41',
#        'Medical_Keyword_42', 'Medical_Keyword_43', 'Medical_Keyword_44',
#        'Medical_Keyword_45', 'Medical_Keyword_46', 'Medical_Keyword_47',
#        'Medical_Keyword_48'],
#       dtype='object', length=127)

# %%
check_nan = df_test.isna().sum()
check_nan[check_nan > 0]
# Out:
# Employment_Info_1          3
# Employment_Info_4       2137
# Employment_Info_6       3787
# Insurance_History_5     8105
# Family_Hist_2           9880
# Family_Hist_3          11064
# Family_Hist_4           6677
# Family_Hist_5          13624
# Medical_History_1       2972
# Medical_History_10     19564
# Medical_History_15     14864
# Medical_History_24     18585
# Medical_History_32     19414
# dtype: int64

# %%
total_miss = df_test.isna().sum().sort_values(ascending = False)
percent = ((df_test.isna().sum()/df_test.shape[0])*100).sort_values(ascending = False)

total_miss = total_miss[total_miss > 0]
percent = percent[percent > 0]

missing_data = pd.concat([total_miss, percent], axis = 1, keys = ['Total Miss', 'Percent'])
missing_data.reset_index(inplace=True)
missing_data.rename(columns={'index': 'Columns'}, inplace=True)
missing_data
# Out:
#                 Columns  Total Miss    Percent
# 0    Medical_History_10       19564  98.983051
# 1    Medical_History_32       19414  98.224134
# 2    Medical_History_24       18585  94.029851
# 3    Medical_History_15       14864  75.203643
# 4         Family_Hist_5       13624  68.929927
# 5         Family_Hist_3       11064  55.977738
# 6         Family_Hist_2        9880  49.987351
# 7   Insurance_History_5        8105  41.006830
# 8         Family_Hist_4        6677  33.781938
# 9     Employment_Info_6        3787  19.160132
# 10    Medical_History_1        2972  15.036681
# 11    Employment_Info_4        2137  10.812041
# 12    Employment_Info_1           3   0.015178

# %%
plt.figure(figsize=(10, 6))
plt.barh(missing_data['Columns'], missing_data['Percent'], color='royalblue')
plt.xlabel('Percentage of Missing Values')
plt.ylabel('Columns')
plt.title('Missing Values Percentage by Column')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.show()

# %%
# Lọc những cột có tỷ lệ Null trên 30%
nacols_above30 = missing_data[missing_data['Percent'] > 30]['Columns']
nacols_above30
# Out:
# 0     Medical_History_10
# 1     Medical_History_32
# 2     Medical_History_24
# 3     Medical_History_15
# 4          Family_Hist_5
# 5          Family_Hist_3
# 6          Family_Hist_2
# 7    Insurance_History_5
# 8          Family_Hist_4
# Name: Columns, dtype: object

# %%
df_test = df_test.drop(columns = nacols_above30, axis = 1)
df_test.shape
# Out:
# (19765, 118)

# %%
check_nan = df_test.isna().sum()
check_nan[check_nan > 0]
# Out:
# Employment_Info_1       3
# Employment_Info_4    2137
# Employment_Info_6    3787
# Medical_History_1    2972
# dtype: int64

# %%
columns_to_fill = ['Employment_Info_1', 'Employment_Info_4', 'Employment_Info_6', 'Medical_History_1']
df_test[columns_to_fill] = df_test[columns_to_fill].fillna(df_test[columns_to_fill].mean())

# %%
check_nan = df_test.isna().sum()
check_nan[check_nan > 0]
# Out:
# Series([], dtype: int64)

# %%
test_duplicated = df_test.duplicated().sum()
test_duplicated
# Out:
# 0

# %%
df_test_new = df_test[['BMI', 'Wt', 'Medical_History_23', 'Medical_Keyword_15',
       'Medical_Keyword_3', 'Medical_History_4', 'Medical_History_39',
       'Ins_Age', 'Product_Info_4', 'Medical_Keyword_48', 'Medical_History_6',
       'Medical_History_16', 'Medical_History_13', 'Medical_History_40',
       'InsuredInfo_6', 'Insurance_History_2', 'Employment_Info_3',
       'Medical_History_30', 'Medical_Keyword_23', 'Medical_History_33',
       'Medical_Keyword_25', 'InsuredInfo_5', 'InsuredInfo_7',
       'Medical_Keyword_42', 'Ht', 'Medical_Keyword_38', 'Medical_History_28',
       'Medical_History_18']]
df_test_new
# Out:
#             BMI        Wt  Medical_History_23  Medical_Keyword_15  \
# 0      0.472262  0.338912                   1                   1
# 1      0.484984  0.311715                   3                   0
# 2      0.519103  0.320084                   3                   0
# 3      0.486962  0.267782                   3                   0
# 4      0.428718  0.246862                   1                   0
# ...         ...       ...                 ...                 ...
# 19760  0.284929  0.152720                   3                   0
# 19761  0.446361  0.225941                   3                   0
# 19762  0.655973  0.414226                   1                   1
# 19763  0.818698  0.529289                   3                   0
# 19764  0.539563  0.382845                   1                   1
#
#        Medical_Keyword_3  Medical_History_4  Medical_History_39   Ins_Age  \
# 0                      0                  2                   3  0.611940
# 1                      0                  1                   3  0.626866
# 2                      0                  1                   3  0.582090
# 3                      0                  2                   3  0.522388
# 4                      0                  1                   3  0.298507
# ...                  ...                ...                 ...       ...
# 19760                  0                  2                   3  0.537313
# 19761                  0                  2                   3  0.134328
# 19762                  0                  1                   3  0.850746
# 19763                  0                  2                   3  0.522388
# 19764                  0                  1                   3  0.343284
#
#        Product_Info_4  Medical_Keyword_48  ...  Medical_Keyword_23  \
# 0            0.487179                   0  ...                   0
# 1            0.076923                   0  ...                   0
# 2            0.144667                   0  ...                   1
# 3            0.151709                   1  ...                   0
# 4            0.076923                   0  ...                   0
# ...               ...                 ...  ...                 ...
# 19760        0.128205                   0  ...                   0
# 19761        0.230769                   0  ...                   0
# 19762        0.076923                   0  ...                   0
# 19763        0.487179                   0  ...                   0
# 19764        1.000000                   0  ...                   1
#
#        Medical_History_33  Medical_Keyword_25  InsuredInfo_5  InsuredInfo_7  \
# 0                       3                   1              1              1
# 1                       3                   0              1              1
# 2                       1                   1              1              1
# 3                       3                   0              1              1
# 4                       3                   1              1              1
# ...                   ...                 ...            ...            ...
# 19760                   3                   0              1              1
# 19761                   3                   0              1              1
# 19762                   3                   0              1              1
# 19763                   3                   0              1              1
# 19764                   1                   0              1              1
#
#        Medical_Keyword_42        Ht  Medical_Keyword_38  Medical_History_28  \
# 0                       0  0.781818                   0                   1
# 1                       0  0.727273                   0                   1
# 2                       0  0.709091                   0                   1
# 3                       0  0.654545                   0                   2
# 4                       0  0.672727                   0                   1
# ...                   ...       ...                 ...                 ...
# 19760                   0  0.636364                   0                   1
# 19761                   0  0.618182                   0                   1
# 19762                   0  0.727273                   0                   1
# 19763                   0  0.745455                   0                   1
# 19764                   0  0.781818                   0                   1
#
#        Medical_History_18
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 19760                   1
# 19761                   1
# 19762                   1
# 19763                   1
# 19764                   1
#
# [19765 rows x 28 columns]

# %% [markdown]
# # **Build Model**

# %%
X = df_train_new.drop(['Response'], axis = 1)
y = df_train_new['Response']

# %%
y.value_counts().plot.pie(autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state = 42)
X_res, y_res = ros.fit_resample(X, y)

ax = y_res.value_counts().plot.pie(autopct = '%.2f')

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.3, shuffle = True, random_state = 42)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, shuffle = True, random_state = 42)

# %%
# Chuẩn hoá dữ liệu
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Check the shape of train dataset
print(X_train.shape,y_train.shape)

# Check the shape of test dataset
print(X_test.shape, y_test.shape)
# Out:
# (109138, 28) (109138,)
# (46774, 28) (46774,)

# %% [markdown]
# ### **Random Forest Classifier Model**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
modelRf = RandomForestClassifier()

# %%
rf_params = {
    'n_estimators': [50, 100, 200],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [None, 10, 20, 30],
    'criterion': ['gini', 'entropy']
}

# %%
grid_search = GridSearchCV(estimator = modelRf, param_grid = rf_params, n_jobs = -1, cv = 5, scoring = 'accuracy')
grid_result = grid_search.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(

# %%
# Lấy kết quả của cross-validation
cv_results = grid_result.cv_results_

combined_info = list(zip(cv_results['params'], cv_results['mean_test_score']))
sorted_info = sorted(combined_info, key=lambda x: x[1], reverse=True)

print("Parameters and Evaluation Scores:")
for params, score in sorted_info:
    print(f"Parameters: {params}, Score: {score}")
# Out:
# Parameters and Evaluation Scores:
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}, Score: 0.8542670532305452
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}, Score: 0.8542395530065715
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}, Score: 0.8541479334482742
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}, Score: 0.8535065415489802
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}, Score: 0.8534515650285069
# Parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 200}, Score: 0.8533965868289128
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 100}, Score: 0.8531492006724981
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 100}, Score: 0.8529659489624958
# Parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 100}, Score: 0.8527735237946853
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}, Score: 0.8525261305020063
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 50}, Score: 0.8516556758542209
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 50}, Score: 0.8512891485067422
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 50}, Score: 0.851270835173545
# Parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 50}, Score: 0.8508218482926097
# Parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'log2', 'n_estimators': 200}, Score: 0.8507485521422357
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 50}, Score: 0.8507393891789332
# Parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'log2', 'n_estimators': 100}, Score: 0.8498139722832029
# Parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'log2', 'n_estimators': 50}, Score: 0.8477798464828364
# Parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 200}, Score: 0.8470101877896183
# Parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 100}, Score: 0.8454525255864669
# Parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 50}, Score: 0.8436108224352292
# Parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 'log2', 'n_estimators': 200}, Score: 0.8435466720371674
# Parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 'log2', 'n_estimators': 100}, Score: 0.842621238350227
# Parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 'log2', 'n_estimators': 50}, Score: 0.8399823641081706
# Parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 200}, Score: 0.7666807301446104
# Parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 100}, Score: 0.7657919180867013
# Parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 50}, Score: 0.7617053518934301
# Parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 100}, Score: 0.7518646319682861
# Parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 200}, Score: 0.7514705863462829
# Parameters: {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 200}, Score: 0.7490883023624082
# Parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 50}, Score: 0.7467884086482488
# Parameters: {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 100}, Score: 0.7465685638542724
# Parameters: {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 50}, Score: 0.7461287550487284
# Parameters: {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 200}, Score: 0.7370301738631568
# Parameters: {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 100}, Score: 0.7353625636564216
# Parameters: {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 50}, Score: 0.7315509006347489
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 200}, Score: 0.49892798828483986
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 200}, Score: 0.49885467240479403
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}, Score: 0.49714124024528294
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}, Score: 0.49702213557510094
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 200}, Score: 0.4969488322884625
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 50}, Score: 0.49658233012779895
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 200}, Score: 0.4960142138096469
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 100}, Score: 0.49549199542449596
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 100}, Score: 0.4953637068019991
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 50}, Score: 0.4943832424429333
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 50}, Score: 0.4939343071949688
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 50}, Score: 0.4937327408924288

# %%
print(grid_result.best_params_) # In ra bộ tham số tốt nhất
print(grid_result.best_score_)
# Out:
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}
# 0.8542670532305452

# %%
modelRandForest = modelRf.set_params(**grid_result.best_params_)
modelRandForest.fit(X_train, y_train)
y_pred = modelRandForest.predict(X_test)

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize = (8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds', xticklabels = modelRandForest.classes_, yticklabels = modelRandForest.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.89      0.91      0.90      5875
#            2       0.90      0.89      0.90      5949
#            3       0.98      1.00      0.99      5798
#            4       0.95      1.00      0.98      5806
#            5       0.92      0.95      0.94      5935
#            6       0.80      0.74      0.77      5829
#            7       0.82      0.86      0.84      5871
#            8       0.81      0.73      0.77      5711
#
#     accuracy                           0.89     46774
#    macro avg       0.88      0.89      0.89     46774
# weighted avg       0.88      0.89      0.89     46774

# %% [markdown]
# ### **Multilayer Perceptron (MLP)**

# %%
# from sklearn.neural_network import MLPClassifier

# %%
# mlp_model = MLPClassifier(max_iter = 5000)

# %%
# mlp_params = {
#     'hidden_layer_sizes': [(20,), (50,), (100,)],
#     'activation': ['relu'],
#     'solver': ['adam'],
#     'alpha': [0.0001, 0.001],
#     'learning_rate': ['constant', 'adaptive']
# }

# %%
# grid_search = GridSearchCV(estimator = mlp_model, param_grid = mlp_params, n_jobs = -1, cv = 5, scoring = 'accuracy')
# grid_result = grid_search.fit(X_train, y_train)

# %%
# # Lấy kết quả của cross-validation
# cv_results = grid_result.cv_results_

# combined_info = list(zip(cv_results['params'], cv_results['mean_test_score']))
# sorted_info = sorted(combined_info, key=lambda x: x[1], reverse=True)

# print("Parameters and Evaluation Scores:")
# for params, score in sorted_info:
#     print(f"Parameters: {params}, Score: {score}")

# %%
# print(grid_result.best_params_) # In ra bộ tham số tốt nhất
# print(grid_result.best_score_)

# %%
# modelMLP = mlp_model.set_params(**grid_result.best_params_)
# modelMLP.fit(X_train, y_train)
# y_pred = modelMLP.predict(X_test)

# %%
# conf_matrix = confusion_matrix(y_test, y_pred)

# plt.figure(figsize = (8, 6))
# sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds', xticklabels = modelMLP.classes_, yticklabels = modelMLP.classes_)
# plt.title('Confusion Matrix')
# plt.xlabel('Predicted Label')
# plt.ylabel('True Label')
# plt.show()

# %%
# print(classification_report(y_test, y_pred))

# %% [markdown]
# ### **K-Nearest Neighbors**

# %%
# from sklearn.neighbors import KNeighborsClassifier

# %%
# k_fold = StratifiedKFold()

# %%
# modelKNN = KNeighborsClassifier()

# %%
# knn_params = {
#     "n_neighbors": range(3, 30, 3),
#     "weights": ['uniform', 'distance'],
#     "metric": ['euclidean'],
#     "algorithm": ['kd_tree', 'ball_tree']
# }

# %%
# grid_search = GridSearchCV(estimator = modelKNN, param_grid = knn_params, n_jobs = -1, cv = k_fold, scoring = 'accuracy')
# grid_result = grid_search.fit(X_train, y_train)

# %%
# # Lấy kết quả của cross-validation
# cv_results = grid_result.cv_results_

# combined_info = list(zip(cv_results['params'], cv_results['mean_test_score']))
# sorted_info = sorted(combined_info, key = lambda x: x[1], reverse=True)

# print("Parameters and Evaluation Scores:")
# for params, score in sorted_info:
#     print(f"Parameters: {params}, Score: {score}")

# %%
# print(grid_result.best_params_)
# print(grid_result.best_score_)

# %%
# final_model = modelKNN.set_params(**grid_result.best_params_)
# final_model.fit(X_train, y_train)
# y_pred = final_model.predict(X_test)

# %%
X_train = df_train_new.drop(['Response'], axis = 1)
y_train = df_train_new['Response']
X_test = df_test_new

# %% [markdown]
# **Đánh giá mô hình Random Forest trên tập Test**

# %%
modelRandForest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features='log2', n_estimators=200)

# %%
y_pred = modelRandForest.predict(X_test)

# %%
y_pred
# Out:
# array([7, 8, 7, ..., 1, 2, 6])

# %%
y_pred.shape
# Out:
# (19765,)

# %%
# file_name = 'Rf_predictions.txt'

# # Mở file TXT để ghi
# with open(file_name, 'w') as file:
#     # Ghi kết quả dự đoán vào file
#     for pred in y_pred:
#         file.write(str(pred) + '\n')

# %% [markdown]
# **Đánh giá mô hình MLP trên tập Test**

# %%
# modelMLP.fit(X_train, y_train)

# %%
# y_pred = modelMLP.predict(X_test)

# %%
# y_pred

# %%
# y_pred.shape
